# %%
import flask
import telebot  
import conf 
import re

WEBHOOK_URL_BASE = "https://{}:{}".format(conf.WEBHOOK_HOST, conf.WEBHOOK_PORT)
WEBHOOK_URL_PATH = "/{}/".format(conf.TOKEN)

bot = telebot.TeleBot(conf.TOKEN, threaded=False)

bot.remove_webhook()
bot.set_webhook(url=WEBHOOK_URL_BASE+WEBHOOK_URL_PATH)

app = flask.Flask(__name__)

@bot.message_handler(commands=['start', 'help'])
def send_welcome(message):
	bot.send_message(message.chat.id, "Привет! Я бот, который считает, сколько слов в твоём сообщении.")
    
@bot.message_handler(func=lambda m: True)
def count_words(message):
    mes = message.text
    mes = re.sub('[,.!?;:#%^)(*]', ' ', mes)
    reply = len(mes.split())
    bot.send_message(message.chat.id, 'Количество слов в твоём сообщении: ' + str(reply))
    
    
@app.route('/', methods=['GET', 'HEAD'])
def index():
    return 'ok'

@app.route(WEBHOOK_URL_PATH, methods=['POST'])
def webhook():
    if flask.request.headers.get('content-type') == 'application/json':
        json_string = flask.request.get_data().decode('utf-8')
        update = telebot.types.Update.de_json(json_string)
        bot.process_new_updates([update])
        return ''
    else:
        flask.abort(403)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\ион\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     375             try:  # Python 2.7, use buffering of HTTP responses
# --> 376                 httplib_response = conn.getresponse(buffering=True)
#     377             except TypeError:  # Python 2.6 and older
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# ConnectionResetError                      Traceback (most recent call last)
# C:\Users\ион\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     558                                                   timeout=timeout_obj,
# --> 559                                                   body=body, headers=headers)
#     560
#
# C:\Users\ион\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     377             except TypeError:  # Python 2.6 and older
# --> 378                 httplib_response = conn.getresponse()
#     379         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# C:\Users\ион\Anaconda3\lib\http\client.py in getresponse(self)
#    1173             try:
# -> 1174                 response.begin()
#    1175             except ConnectionError:
#
# C:\Users\ион\Anaconda3\lib\http\client.py in begin(self)
#     281         while True:
# --> 282             version, status, reason = self._read_status()
#     283             if status != CONTINUE:
#
# C:\Users\ион\Anaconda3\lib\http\client.py in _read_status(self)
#     242     def _read_status(self):
# --> 243         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     244         if len(line) > _MAXLINE:
#
# C:\Users\ион\Anaconda3\lib\socket.py in readinto(self, b)
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#
# C:\Users\ион\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#     923                   self.__class__)
# --> 924             return self.read(nbytes, buffer)
#     925         else:
#
# C:\Users\ион\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     785         try:
# --> 786             return self._sslobj.read(len, buffer)
#     787         except SSLError as x:
#
# C:\Users\ион\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     569         if buffer is not None:
# --> 570             v = self._sslobj.read(len, buffer)
#     571         else:
#
# ConnectionResetError: [WinError 10054] Удаленный хост принудительно разорвал существующее подключение
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# C:\Users\ион\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     375                     retries=self.max_retries,
# --> 376                     timeout=timeout
#     377                 )
#
# C:\Users\ион\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     608             retries = retries.increment(method, url, error=e, _pool=self,
# --> 609                                         _stacktrace=sys.exc_info()[2])
#     610             retries.sleep()
#
# C:\Users\ион\Anaconda3\lib\site-packages\requests\packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     246             if read is False:
# --> 247                 raise six.reraise(type(error), error, _stacktrace)
#     248             elif read is not None:
#
# C:\Users\ион\Anaconda3\lib\site-packages\requests\packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     308         if value.__traceback__ is not tb:
# --> 309             raise value.with_traceback(tb)
#     310         raise value
#
# C:\Users\ион\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     558                                                   timeout=timeout_obj,
# --> 559                                                   body=body, headers=headers)
#     560
#
# C:\Users\ион\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     377             except TypeError:  # Python 2.6 and older
# --> 378                 httplib_response = conn.getresponse()
#     379         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# C:\Users\ион\Anaconda3\lib\http\client.py in getresponse(self)
#    1173             try:
# -> 1174                 response.begin()
#    1175             except ConnectionError:
#
# C:\Users\ион\Anaconda3\lib\http\client.py in begin(self)
#     281         while True:
# --> 282             version, status, reason = self._read_status()
#     283             if status != CONTINUE:
#
# C:\Users\ион\Anaconda3\lib\http\client.py in _read_status(self)
#     242     def _read_status(self):
# --> 243         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     244         if len(line) > _MAXLINE:
#
# C:\Users\ион\Anaconda3\lib\socket.py in readinto(self, b)
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#
# C:\Users\ион\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#     923                   self.__class__)
# --> 924             return self.read(nbytes, buffer)
#     925         else:
#
# C:\Users\ион\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     785         try:
# --> 786             return self._sslobj.read(len, buffer)
#     787         except SSLError as x:
#
# C:\Users\ион\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     569         if buffer is not None:
# --> 570             v = self._sslobj.read(len, buffer)
#     571         else:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, 'Удаленный хост принудительно разорвал существующее подключение', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-3-5853da39fded> in <module>()
#      13
#      14 if __name__ == '__main__':
# ---> 15     bot.polling(none_stop=True)
#
# C:\Users\ион\Anaconda3\lib\site-packages\telebot\__init__.py in polling(self, none_stop, interval, timeout)
#     220         """
#     221         if self.threaded:
# --> 222             self.__threaded_polling(none_stop, interval, timeout)
#     223         else:
#     224             self.__non_threaded_polling(none_stop, interval, timeout)
#
# C:\Users\ион\Anaconda3\lib\site-packages\telebot\__init__.py in __threaded_polling(self, none_stop, interval, timeout)
#     243                 or_event.wait()  # wait for polling thread finish, polling thread error or thread pool error
#     244
# --> 245                 polling_thread.raise_exceptions()
#     246                 self.worker_pool.raise_exceptions()
#     247
#
# C:\Users\ион\Anaconda3\lib\site-packages\telebot\util.py in raise_exceptions(self)
#      71         def raise_exceptions(self):
#      72             if self.exception_event.is_set():
# ---> 73                 six.reraise(self.exc_info[0], self.exc_info[1], self.exc_info[2])
#      74
#      75         def clear_exceptions(self):
#
# C:\Users\ион\Anaconda3\lib\site-packages\six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
#     685             raise value.with_traceback(tb)
# --> 686         raise value
#     687
#     688 else:
#
# C:\Users\ион\Anaconda3\lib\site-packages\telebot\util.py in run(self)
#      52                     self.received_task_event.set()
#      53
# ---> 54                     task(*args, **kwargs)
#      55                     logger.debug("Task complete")
#      56                     self.done_event.set()
#
# C:\Users\ион\Anaconda3\lib\site-packages\telebot\__init__.py in __retrieve_updates(self, timeout)
#     134             logger.debug('Skipped {0} pending messages'.format(self.__skip_updates()))
#     135             self.skip_pending = False
# --> 136         updates = self.get_updates(offset=(self.last_update_id + 1), timeout=timeout)
#     137         self.process_new_updates(updates)
#     138
#
# C:\Users\ион\Anaconda3\lib\site-packages\telebot\__init__.py in get_updates(self, offset, limit, timeout, allowed_updates)
#     104         :return: array of Updates
#     105         """
# --> 106         json_updates = apihelper.get_updates(self.token, offset, limit, timeout, allowed_updates)
#     107         ret = []
#     108         for ju in json_updates:
#
# C:\Users\ион\Anaconda3\lib\site-packages\telebot\apihelper.py in get_updates(token, offset, limit, timeout, allowed_updates)
#     161     if allowed_updates:
#     162         payload['allowed_updates'] = allowed_updates
# --> 163     return _make_request(token, method_url, params=payload)
#     164
#     165
#
# C:\Users\ион\Anaconda3\lib\site-packages\telebot\apihelper.py in _make_request(token, method_name, method, params, files, base_url)
#      40         if 'timeout' in params: read_timeout = params['timeout'] + 10
#      41         if 'connect-timeout' in params: connect_timeout = params['connect-timeout'] + 10
# ---> 42     result = req_session.request(method, request_url, params=params, files=files, timeout=(connect_timeout, read_timeout))
#      43     logger.debug("The server returned: '{0}'".format(result.text.encode('utf8')))
#      44     return _check_result(method_name, result)['result']
#
# C:\Users\ион\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     466         }
#     467         send_kwargs.update(settings)
# --> 468         resp = self.send(prep, **send_kwargs)
#     469
#     470         return resp
#
# C:\Users\ион\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     574
#     575         # Send the request
# --> 576         r = adapter.send(request, **kwargs)
#     577
#     578         # Total elapsed time of the request (approximately)
#
# C:\Users\ион\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     424
#     425         except (ProtocolError, socket.error) as err:
# --> 426             raise ConnectionError(err, request=request)
#     427
#     428         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'Удаленный хост принудительно разорвал существующее подключение', None, 10054, None))

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-f7fc933fe28e> in <module>()
# ----> 1 import pyTelegramBotAPI
#
# ImportError: No module named 'pyTelegramBotAPI'
